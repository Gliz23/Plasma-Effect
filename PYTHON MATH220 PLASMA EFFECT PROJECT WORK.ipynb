# %% [markdown]
# # Plasma Effect

# %% [markdown]
# Plasma Effect: Plasma effects are often used to create wobbly animations in demo products like screen savers. Using mathematical functions like sine, tan, etc, is one way of creating such effects.
#
# (a) Create a grid with x, y ∈ [−π, π]. Plot the function f(x, y) = sin (5 ∗ x). This an over simplified plasma. 2
#
# We first import the modules and libraries we will need.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# We create a grid using the interval -pi and pi by applying linspace to it. We already have two intervals, (x and y) so in order to apply the fuctions we will be given we need a mesh grid. (a1) is a unique variable name which plt.show has been assinged to

# %%
#A) We first define the grid with x and y values ranging
#from  -pi to pi and leave the number of values to be defined
# by the program.

x=np.linspace(-np.pi, np.pi)
y=np.linspace(-np.pi, np.pi)

X,Y = np.meshgrid(x,y)

# Define the function f(x,y) = sin(5*x)
Z1 = np.sin(5*X)

# We create the plot in 3d
fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')
ax.plot_surface(X, Y, Z1)

#We set the labels of the axes
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# We show the 3d plot
a1 = plt.show

#We view the plot in 2d from the z direction
fig = plt.figure()
plt.contourf(X, Y, Z1, 32)

# %% [markdown]
# B) We plot the function  f(x, y) = ((sin^2(3*x) + (sin^2(3*y))/2.
# In order to do it, we define a function in order to vary the values.
#
# (b2) is a unique variable name plt.show for this particular lines of code has been assinged to.

# %%
# We define the second funtion we want to plot(b).
def f(x,y,f,p):
    A= (np.sin(f*x))**p
    B= (np.sin(f*y))**p
    C= (A+B)/2
    return C

# We instantiate the function using values from the question
# and assign it to Z2
Z2 = f(X,Y,3,2)


# We view it in 3d by
# Creating the plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z2)

# Labelling the axes
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# Showing the 3d plot
b2 = plt.show()


#We view it in 2d fron the z direction
fig = plt.figure()
plt.contourf(X, Y, Z2, 50)

# %% [markdown]
# We change the values for the frequency
# and powers to see how it varies.
#
# (c3) is a unique variable name plt.show for this particular lines of code has been assinged to.

# %%
Z3= f(X,Y,5,3)

# We view it in 3d by
# Creating the plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z3)

# Labelling the axes
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# Showing the 3D plot
c3 = plt.show()

# Showing the 2D plot
fig = plt.figure()
plt.contourf(X, Y, Z3, 25)

# %% [markdown]
# (f4) is a unique variable name plt.show for this particular lines of code has been assinged to.
# Z4 is a unique variable name the fuction to be plotted in this question has been assigned to

# %%
Z4= f(X,Y,10,7)

# We view it in 3d by
# Creating the plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z4)

# Labelling the axes
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# Showing the 3D plot
f4 = plt.show()

# Showing the 2D plot
fig = plt.figure()
plt.contourf(X, Y, Z4, 50)

# %% [markdown]
# # Observation
# The frequency increases the values on the z axis.
# The increase in powers causes the peaks to be more pointed.
# The brighter colours on the 2D map shows a higher value on the Z axis.
# The color map in the above plots are set to default.

# %% [markdown]
# C) The next function to plot is f(x,y) = |cos(20(cos^2(20) + sin^2(20))).
#
# (e5) is a unique variable name plt.show for this particular lines of code has been assinged to.
#
# (Z5) is a unique variable name the fuction to be plotted in this question has been assigned to

# %%
# We define the grid with x and y values ranging from -pi to  pi
x=np.linspace(-np.pi, np.pi)
y=np.linspace(-np.pi, np.pi)

X,Y = np.meshgrid(x,y)

# We define the function f(x,y) = |cos(20(cos^2(20) + sin^2(20)))
def g(x,y):
    W =  (np.cos(20*x)**2) + (np.sin(20*y)**2)
    V = np.cos(20*W)
    return V

# We instantiate the function and assign it to Z5
Z5= g(X,Y)

# We plot the function in 3d
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z5)

# Label the axes 
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# Show the plot in 3d
e5 = plt.show()

# We then show the plot in 2d and view in the z direction
fig = plt.figure()
plt.contourf(X, Y, Z5, 50)

# %% [markdown]
# Now we are going to create a colour image with the following parameters
#
# r = cos(x) + sin(y)
#
# red = cos(yr)
#
# green = cos(xyr)
#
# blue = sin(xr)
#
#
# (f6) and (f8) is a unique variable name plt.show for this particular lines of code has been assinged to.
# The first code is with specified number of values for x and y.
# The second code is without specified. Hence the default is 50

# %%
# Define the grid with x and y values ranging from -pi to pi
# But in this case in order to get a clear image we state the
#nmber of x and y values to be 100.


x = np.linspace(-np.pi, np.pi, 100)
y = np.linspace(-np.pi, np.pi, 100)  
X, Y = np.meshgrid(x, y)

# We first define the parameters
r = np.abs(np.cos(X) + np.sin(Y))
red = np.abs(np.cos(Y*r))
green = np.abs(np.cos(X*Y*r))
blue = np.abs(np.sin(X*r))

# We thensStack the parameters to create the RGB color image
rgb = np.stack([red, green, blue], axis=2)

# Create the plot
plt.imshow(rgb)

# Show the plot
f8 = plt.show()


#Without specifying our value number, we have
x = np.linspace(-np.pi, np.pi)
y = np.linspace(-np.pi, np.pi)  
X, Y = np.meshgrid(x, y)

# We first define the parameters
r = np.abs(np.cos(X) + np.sin(Y))
red = np.abs(np.cos(Y*r))
green = np.abs(np.cos(X*Y*r))
blue = np.abs(np.sin(X*r))

# We thensStack the parameters to create the RGB color image
rgb = np.stack([red, green, blue], axis=2)

# Create the plot
plt.imshow(rgb)

# Show the plot
f6 = plt.show()

# %% [markdown]
# Two Plasma effects on my own.

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

# Define the function to be plotted
def f__1(x, y):
    return np.sin(2*x) * np.cos(2*y)

# Set up the grid
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)
Z6 = f__1(X, Y)

# Set up the plot
fig1 = plt.figure()
ax_1 = fig1.add_subplot(111, projection='3d')

# Set up the animation function
def animate1(i):
    ax_1.clear()
    ax_1.set_title('ff(x, y) = sin(2x) * cos(2y)')
    ax_1.set_xlabel('X')
    ax_1.set_ylabel('Y')
    ax_1.set_zlabel('Z')
    ax_1.plot_surface(X, Y, f__1(X - i/20, Y + i/20), cmap = 'jet' )

# Animate the plot
ani1 = animation.FuncAnimation(fig1, animate1, frames=100, interval=50)

# Display the animation
g7 = plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

# Define the function to be plotted
def f__2(x, y):
    return np.sin(2*x) * np.cos(2*y)

# Set up the grid
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)
Z7 = f__2(X, Y)

# Set up the plot
fig2 = plt.figure()
ax2 = fig2.add_subplot(111, projection='3d')

# Set up the animation function
def animate2(i):
    ax2.clear()
    ax2.set_title('f(x, y) = sin(x) + cos(y)')
    ax2.set_xlabel('X')
    ax2.set_ylabel('Y')
    ax2.set_zlabel('Z')
    ax2.plot_surface(X, Y, f__2(X - i/20, Y + i/20), cmap = 'spring' )

# Animate the plot
ani = animation.FuncAnimation(fig2, animate2, frames=100, interval=500)

# Display the animation
h8 = plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Now animate a plasma sequence using the following sequence
#
# v1 = sin (10x + 5t)
#
# v2 = sin (10 (x sin (t/2) + y cos (t/3)) + 5t)
#
# cx = x + *5 sin (t/5)
#
# cy = y + *5 cos (t/3)
#
# v3 = np.sin(((100*(cx^2 + cy^2)+1)^0.5) +t)
#
# v = v1 + v2 + v3
#
# where t is the animation time.
# Show the image as a colour image using the following colour component
# r = 1
# g = cos (πv)
# b = sin (πv)

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

# Define the grid with x and y values ranging from -pi to pi
x = np.linspace(-np.pi, np.pi, 200)
y = np.linspace(-np.pi, np.pi, 200)
X, Y = np.meshgrid(x, y)

# Define the animation time range
t_range = np.linspace(0, 10, 100)

# Set up the plot
fig3 = plt.figure()
 
# Define the animation function
def animate_plasma(t):
    # Define the parameters for the plasma sequence
    v1 = np.sin(10 * X + 5 * t)
    v2 = np.sin(10 * (X * np.sin(t/2) + Y * np.cos(t/3)) + 5 * t)
    cx = X + 0.5 * np.sin(t / 5)
    cy = Y + 0.5 * np.cos(t / 3)
    v3 = np.sin(np.sqrt(100 * (cx**2 + cy**2)) + 1 + t)
    v = v1 + v2 + v3
    r = np.ones_like(v)
    g = np.cos(np.pi * v)
    b = np.sin(np.pi * v)
    img = np.dstack((r,g,b))
    return plt.imshow(img)
    
    
#Create the animation
anim = animation.FuncAnimation(fig3, animate_plasma, frames=200, interval=200, blit = True)

# Show the animation
z = plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
